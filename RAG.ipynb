# %% [markdown]
# <a href="https://colab.research.google.com/github/Ale10chine/Alternating-Criteria-Search/blob/master/RAG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Installing dependencies
